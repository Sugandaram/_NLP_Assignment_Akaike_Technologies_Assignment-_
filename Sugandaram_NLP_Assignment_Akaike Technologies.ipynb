# %%
import spacy
import random

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def get_mca_questions(context: str, num_questions: int):
  doc = nlp(context)

# %%
def generate_mcq_with_multiple_correct(question, correct_answers, other_options, num_options=4):
        options = correct_answers + other_options
        random.shuffle(options)

        mcq = {
            "question": question,
            "options": options,
            "correct_answers": correct_answers
        }

# %%
def generate_variety_question():
        # randomly select the sentence from content
        sentence = random.choice(list(doc.sents))

        # randomly choose non- pronounciation words from sentence as blank word
        blank_word = random.choice([token for token in sentence if not token.is_punct])

        # create a question text with blank word ----
        question_text = sentence.text.replace(blank_word.text, "______")

        #set correct answers to the blank word
        correct_answers = [blank_word.text]

        #generating other possible answers
        other_options = [token.text for token in doc if token.is_alpha and token.text != correct_answers[0]]

        #randonly determine how many correct options
        num_correct_options = random.randint(1, 2)

        #randomly select correct options to the list of options
        correct_answers.extend(random.sample(other_options, num_correct_options))

        # no of incorrect answers
        num_other_options = min(4 - num_correct_options, len(other_options))
        other_options = random.sample(other_options, num_other_options)

        #generationg final MCQ
        mcq = generate_mcq_with_multiple_correct(question_text, correct_answers, other_options)
        return mcq

# %%
#user input for paragraph
context = input("Enter the paragraph: ")

#no of questions user want to generate
num_questions = int(input("Enter the number of questions: "))

#calls the function and generate MCQ questions
mca_questions = get_mca_questions(context, num_questions)
for question in mca_questions:
    print(question)
# Out:
# Enter the paragraph: It is useful to characterize learning problems according to the type of data they use. This is a great help when encountering new challenges, since quite often problems on similar data types can be solved with very similar techniques. For instance natural language processing and bioinformatics use very similar tools for strings of natural language text and for DNA sequences. Vectors constitute the most basic entity we might encounter in our work. For instance, a life insurance company might be interesting in obtaining the vector of variables (blood pressure, heart rate, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a potential customer. A farmer might be interested in determining the ripeness of fruit based on (size, weight, spectral data). An engineer might want to find dependencies in (voltage, current) pairs. Likewise one might want to represent documents by a vector of counts which describe the occurrence of words. The latter is commonly referred to as bag of words features
# Enter the number of questions: 50
# Q1: This is a ______ help when encountering new challenges, since quite often problems on similar data types can be solved with very similar techniques.
# 1. cholesterol
# 2. great
# 3. features
# 4. counts
# 5. commonly
# Correct Options: (b) & (e)
#
# Q2: ______ latter is commonly referred to as bag of words features
# 1. spectral
# 2. size
# 3. smoker
# 4. determining
# 5. The
# Correct Options: (e) & (a)
#
# Q3: ______ is useful to characterize learning problems according to the type of data they use.
# 1. might
# 2. similar
# 3. a
# 4. vector
# 5. It
# Correct Options: (e) & (c) & (d)
#
# Q4: Likewise one might want to represent documents by a vector of counts which ______ the occurrence of words.
# 1. describe
# 2. is
# 3. similar
# 4. latter
# 5. useful
# Correct Options: (a) & (b) & (e)
#
# Q5: It is useful to characterize learning problems according to ______ type of data ______y use.
# 1. might
# 2. the
# 3. data
# 4. An
# 5. fruit
# Correct Options: (b) & (a)
#
# Q6: A farmer might be interested in determining the ripeness of fruit based on (size, weight, ______ data).
# 1. counts
# 2. spectral
# 3. to
# 4. gender
# 5. life
# Correct Options: (b) & (a) & (e)
#
# Q7: Vectors constitute the most basic entity we ______ encounter in our work.
# 1. customer
# 2. similar
# 3. might
# 4. of
# 5. referred
# Correct Options: (c) & (a)
#
# Q8: Likewise one might want to represent documents by a vector of counts which ______ the occurrence of words.
# 1. entity
# 2. describe
# 3. is
# 4. farmer
# 5. encountering
# Correct Options: (b) & (e) & (a)
#
# Q9: For instance natural language processing and bioinformatics use very similar tools for strings of natural language ______ and for DNA sequences.
# 1. entity
# 2. gender
# 3. text
# 4. a
# 5. infer
# Correct Options: (c) & (a) & (b)
#
# Q10: For instance, a life insurance company might ______ interesting in obtaining the vector of variables (blood pressure, heart rate, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a potential customer.
# 1. types
# 2. natural
# 3. obtaining
# 4. strings
# 5. be
# Correct Options: (e) & (d) & (b)
#
# Q11: The latter is commonly referred to as bag of ______ features
# 1. problems
# 2. words
# 3. referred
# 4. be
# 5. ripeness
# Correct Options: (b) & (d)
#
# Q12: For instance, a life insurance company might be interesting in obtaining the vector of variables (blood pressure, ______ rate, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a potential customer.
# 1. basic
# 2. heart
# 3. processing
# 4. to
# 5. in
# Correct Options: (b) & (d)
#
# Q13: Likewise one might want to represent documents ______ a vector of counts which describe the occurrence of words.
# 1. by
# 2. customer
# 3. of
# 4. in
# 5. to
# Correct Options: (a) & (d) & (b)
#
# Q14: The latter is commonly ______ to as bag of words features
# 1. entity
# 2. in
# 3. referred
# 4. similar
# 5. and
# Correct Options: (c) & (d) & (e)
#
# Q15: For ______ natural language processing and bioinformatics use very similar tools for strings of natural language text and for DNA sequences.
# 1. use
# 2. on
# 3. encountering
# 4. instance
# 5. encounter
# Correct Options: (d) & (b) & (a)
#
# Q16: A farmer might be interested in determining the ripeness of fruit based on (size, weight, spectral ______).
# 1. referred
# 2. documents
# 3. data
# 4. might
# 5. dependencies
# Correct Options: (c) & (d)
#
# Q17: This is a great help when encountering ______ challenges, since quite often problems on similar data types can be solved with very similar techniques.
# 1. a
# 2. be
# 3. dependencies
# 4. new
# 5. of
# Correct Options: (d) & (e) & (b)
#
# Q18: Likewise one might ______ to represent documents by a vector of counts which describe the occurrence of words.
# 1. based
# 2. help
# 3. For
# 4. want
# 5. represent
# Correct Options: (d) & (b)
#
# Q19: It ______ useful to characterize learning problems according to the type of data they use.
# 1. is
# 2. for
# 3. one
# 4. level
# 5. useful
# Correct Options: (a) & (c)
#
# Q20: For instance natural language processing and bioinformatics use ______ similar tools for strings of natural language text and for DNA sequences.
# 1. spectral
# 2. similar
# 3. they
# 4. very
# 5. tools
# Correct Options: (d) & (c)
#
# Q21: It is useful to characterize learning problems according to ______ type of data ______y use.
# 1. natural
# 2. characterize
# 3. similar
# 4. similar
# 5. the
# Correct Options: (e) & (a) & (c)
#
# Q22: Vectors constitute the most basic entity ______ might encounter in our work.
# 1. very
# 2. we
# 3. a
# 4. This
# 5. use
# Correct Options: (b) & (c) & (a)
#
# Q23: For instance natural language ______ and bioinformatics use very similar tools for strings of natural language text and for DNA sequences.
# 1. for
# 2. a
# 3. problems
# 4. and
# 5. processing
# Correct Options: (e) & (a)
#
# Q24: For instance natural language processing and bioinformatics use very ______ tools for strings of natural language text and for DNA sequences.
# 1. similar
# 2. language
# 3. language
# 4. to
# 5. of
# Correct Options: (a) & (e) & (d)
#
# Q25: The latter is commonly referred to as bag ______ words features
# 1. level
# 2. problems
# 3. of
# 4. The
# 5. infer
# Correct Options: (c) & (b)
#
# Q26: It is useful to characterize learning problems ______ to the type of data they use.
# 1. words
# 2. according
# 3. cholesterol
# 4. might
# 5. the
# Correct Options: (b) & (d) & (a)
#
# Q27: ______ engineer might want to find dependencies in (voltage, current) pairs.
# 1. problems
# 2. expectancy
# 3. An
# 4. The
# 5. similar
# Correct Options: (c) & (a)
#
# Q28: It is useful ______ characterize learning problems according ______ the type of data they use.
# 1. For
# 2. to
# 3. interesting
# 4. of
# 5. voltage
# Correct Options: (b) & (c)
#
# Q29: An engineer might ______ to find dependencies in (voltage, current) pairs.
# 1. want
# 2. be
# 3. natural
# 4. customer
# 5. a
# Correct Options: (a) & (d) & (b)
#
# Q30: For instance natural language processing and bioinformatics ______ very similar tools for strings of natural language text and for DNA sequences.
# 1. pairs
# 2. smoker
# 3. quite
# 4. fruit
# 5. use
# Correct Options: (e) & (d) & (a)
#
# Q31: An engineer ______ want to find dependencies in (voltage, current) pairs.
# 1. of
# 2. very
# 3. company
# 4. might
# 5. latter
# Correct Options: (d) & (a)
#
# Q32: A farmer might be interested in determining the ripeness of fruit ______ on (size, weight, spectral data).
# 1. Vectors
# 2. based
# 3. similar
# 4. in
# 5. level
# Correct Options: (b) & (e)
#
# Q33: This is a great ______ when encountering new challenges, since quite often problems on similar data types can be solved with very similar techniques.
# 1. bag
# 2. most
# 3. help
# 4. A
# 5. height
# Correct Options: (c) & (b) & (e)
#
# Q34: It is useful ______ characterize learning problems according ______ the type of data they use.
# 1. is
# 2. be
# 3. to
# 4. characterize
# 5. fruit
# Correct Options: (c) & (b)
#
# Q35: An engineer might want to find dependencies in (voltage, ______) pairs.
# 1. current
# 2. occurrence
# 3. new
# 4. characterize
# 5. interested
# Correct Options: (a) & (e) & (d)
#
# Q36: Vectors constitute the most ______ entity we might encounter in our work.
# 1. basic
# 2. of
# 3. engineer
# 4. challenges
# 5. to
# Correct Options: (a) & (b) & (c)
#
# Q37: The latter is commonly referred to as ______ of words features
# 1. An
# 2. It
# 3. bag
# 4. Likewise
# 5. use
# Correct Options: (c) & (a)
#
# Q38: The latter is commonly referred to as bag of words ______
# 1. to
# 2. features
# 3. a
# 4. to
# 5. interesting
# Correct Options: (b) & (c)
#
# Q39: This is a great help when encountering new challenges, since quite ______ problems on similar data types can be solved with very similar techniques.
# 1. a
# 2. the
# 3. often
# 4. vector
# 5. obtaining
# Correct Options: (c) & (e) & (a)
#
# Q40: A farmer might be interested in determining the ______ of fruit based on (size, weight, spectral data).
# 1. vector
# 2. words
# 3. the
# 4. occurrence
# 5. ripeness
# Correct Options: (e) & (a) & (b)
#
# Q41: For instance, a life insurance company might be interesting in obtaining the vector of variables (blood pressure, heart rate, height, weight, ______ level, smoker, gender) to infer the life expectancy of a potential customer.
# 1. can
# 2. in
# 3. a
# 4. cholesterol
# 5. occurrence
# Correct Options: (d) & (c) & (e)
#
# Q42: It is ______ful to characterize learning problems according to the type of data they ______.
# 1. cholesterol
# 2. use
# 3. in
# 4. techniques
# 5. The
# Correct Options: (b) & (c) & (a)
#
# Q43: For instance, a life insurance company might ______ interesting in obtaining the vector of variables (blood pressure, heart rate, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a potential customer.
# 1. when
# 2. a
# 3. be
# 4. techniques
# 5. bioinformatics
# Correct Options: (c) & (d)
#
# Q44: For instance, a life insurance company might be interesting in obtaining the vector of variables (blood pressure, heart ______, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a potential customer.
# 1. might
# 2. is
# 3. find
# 4. gender
# 5. rate
# Correct Options: (e) & (c)
#
# Q45: For instance, a life insurance company might be interesting in obtaining the vector of variables (blood pressure, heart rate, height, weight, cholesterol level, smoker, gender) to infer the life expectancy of a ______ customer.
# 1. our
# 2. find
# 3. types
# 4. most
# 5. potential
# Correct Options: (e) & (c)
#
# Q46: ______ latter is commonly referred to as bag of words features
# 1. counts
# 2. might
# 3. An
# 4. The
# 5. is
# Correct Options: (d) & (b)
#
# Q47: Th______ ______ a great help when encountering new challenges, since quite often problems on similar data types can be solved with very similar techniques.
# 1. as
# 2. vector
# 3. natural
# 4. data
# 5. is
# Correct Options: (e) & (d)
#
# Q48: An ______ might want to find dependencies in (voltage, current) pairs.
# 1. be
# 2. types
# 3. spectral
# 4. words
# 5. engineer
# Correct Options: (e) & (b) & (d)
#
# Q49: Likewise one might want to represent documents by a vector of counts which describe the ______ of words.
# 1. often
# 2. occurrence
# 3. represent
# 4. learning
# 5. obtaining
# Correct Options: (b) & (e) & (d)
#
# Q50: It is useful to characterize learning problems according to the type of ______ they use.
# 1. quite
# 2. data
# 3. occurrence
# 4. very
# 5. variables
# Correct Options: (b) & (a)
